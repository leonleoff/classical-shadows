# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Imports 
from classical_shadow_1_clifford import ClassicalShadow_1_CLIFFORD
from qiskit import QuantumCircuit

# %%
# Setup Experiment

class BellState_Shadow(ClassicalShadow_1_CLIFFORD):

    def get_num_qubits(self) -> int:
        raise NotImplementedError("This method should be implemented by subclasses")
    
    def get_state_circuit(self) -> QuantumCircuit:
        """ "Returns the quantum circuit that prepare the state of interest."""
        raise NotImplementedError("This method should be implemented by subclasses")

    def run_cuircuit_and_get_measurment(self, circuit):
        raise NotImplementedError("This function is not yet implemented.")
